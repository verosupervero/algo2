# %% [markdown]
# # Estimación de la complejidad

# %%
from profile_grafo import *
import numpy as np
import matplotlib.pyplot as plt

# %%
aux=[]
cant_lotes=100
largo_lote=100
for i in range(0,50):
    aux.append(profile_agregar_vertice(largo_lote=largo_lote, cant_lotes=cant_lotes))

tagregar = np.array(aux)
plt.plot(tagregar.mean(axis=0))

# %%
aux=[]
for i in range(0,50):
    aux.append(profile_agregar_arista())

tagregar = np.array(aux)
plt.plot(tagregar.mean(axis=0))
# esos picos?

# %%
np.shape(tagregar)
# Out:
# (50, 20)

# %%
profile_agregar_arista()
# Out:
# [0.019719400999999692,
#  0.019447472000003074,
#  0.018956520999999782,
#  0.018770494000001747,
#  0.018693124999998645,
#  0.018611774000000025,
#  0.018808039999999693,
#  0.018662974000001498,
#  0.018618601000000012,
#  0.01876821799999817,
#  0.019423010000000573,
#  0.01967730399999823,
#  0.024958301000001626,
#  0.01867321399999966,
#  0.018483773999999897,
#  0.018737499000000213,
#  0.018745462999998352,
#  0.01858446700000016,
#  0.0186914189999996,
#  0.018626566000001787]

# %%
nlote=0
range(0+nlote*largo_lote,(nlote+1)*largo_lote)
# Out:
# range(0, 100)

# %%
import math
math.floor(3.2)
# Out:
# 3
